# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## PRACTICA OBLIGATORIA: VISUALIZACION BASICA

# %% [markdown]
# * La práctica obligatoria de esta unidad consiste en un único ejercicio de construcción de gráficas. Descarga este notebook en tu ordenador y trabaja en local. Ten en cuenta que tendrás que descar los directorios de imágenes y datos adicionales, si los hubiera.
# * Recuerda que debes subirla a tu repositorio personal antes de la sesión en vivo para que puntúe adecuadamente.
# * Recuerda también que no es necesario que esté perfecta, sólo es necesario que se vea el esfuerzo.
# * Esta práctica se resolverá en la sesión en vivo correspondiente y la solución se publicará en el repo del curso.

# %% [markdown]
# ### Ejercicio 0

# %% [markdown]
# Importa los paquetes y módulos que necesites a lo largo del notebook.

# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd

# %% [markdown]
# ## #1

# %% [markdown]
# ### #1.1

# %% [markdown]
# "./data/california_cities.csv"Carga el dataset de casas de California que está en la ruta . Muestra parte de su contenido y su descripción. Deshazte de las filas con nulos.

# %%
import pandas as pd

# Ruta al archivo CSV
file_path = "./data/california_cities.csv"

# Cargar el CSV en un DataFrame
df = pd.read_csv(file_path)

# Mostrar las primeras filas del DataFrame
print(df.head())
# Out:
#    Unnamed: 0         city       latd       longd  elevation_m  elevation_ft  \
# 0           0     Adelanto  34.576111 -117.432778        875.0        2871.0
# 1           1  AgouraHills  34.153333 -118.761667        281.0         922.0
# 2           2      Alameda  37.756111 -122.274444          NaN          33.0
# 3           3       Albany  37.886944 -122.297778          NaN          43.0
# 4           4     Alhambra  34.081944 -118.135000        150.0         492.0
#
#    population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 0             31765            56.027           56.009             0.018
# 1             20330             7.822            7.793             0.029
# 2             75467            22.960           10.611            12.349
# 3             18969             5.465            1.788             3.677
# 4             83089             7.632            7.631             0.001
#
#    area_total_km2  area_land_km2  area_water_km2  area_water_percent
# 0         145.107        145.062           0.046                0.03
# 1          20.260         20.184           0.076                0.37
# 2          59.465         27.482          31.983               53.79
# 3          14.155          4.632           9.524               67.28
# 4          19.766         19.763           0.003                0.01

# %% [markdown]
# ### #1.2
#
# Recrea la siguiente figura, para ello construye en apartados separados cada gráfico y luego haz un apartado en el que se junten los cuatro. Las figuras son:
# 1. Las ciudades más pobladas, con los numeros de las poblaciones (tendrás que usar texto y recordar que para centrarlos se necesita poner el argumento `ha` a "center"). (Colores: azul, gris, aceituna, marrón, con trasparencia)
# 2. Histograma del área total ocupada por las ciudades. (50 bins, fuente = "Bradley Hand itc", tamaño 18, color azul acero)
# 3. El scatter de área de agua de un ciudad con su poblacion.
# 4. El boxplot de la altura de las ciudades.

# %% [markdown]
# ![figura_ejempo.png](attachment:figura_ejempo.png)

# %% [markdown]
# ### #1.3
#
# Graba la figura en un archivo y sube el archivo a tu repo personal también.

# %%
# Datos proporcionados
data = {
    "city": ["Los Angeles", "San Diego", "Sacramento", "Anaheim", "Santa Ana"],
    "population": [3884307, 1345895, 466488, 336000, 324528],
    "area_km2": [1214, 964, 100, 50, 42],
    "water_km2": [121, 70, 20, 10, 5],
}

# Crear el DataFrame
df_cities = pd.DataFrame(data)

# Generar altitudes simuladas para 100 ciudades
altitude_m = np.random.randint(0, 2500, 100)

# Crear la figura principal
plt.figure(figsize=(15, 12))

# --- 1. Gráfico de barras (Ciudades más pobladas)
plt.subplot(2, 2, 1)
colors = ["blue", "gray", "red", "brown", "olive"]
plt.bar(df_cities["city"], df_cities["population"], color=colors, alpha=0.7)
for i, pop in enumerate(df_cities["population"]):
    plt.text(i, pop + 50000, f"{pop:,}", ha="center", fontsize=10)
plt.title("Ciudades más pobladas de California", fontsize=16)
plt.ylabel("Habitantes (miles)", fontsize=12)

# --- 2. Histograma del área total
plt.subplot(2, 2, 2)
plt.hist(df_cities["area_km2"], bins=50, color="steelblue", alpha=0.7, label="Hist Area")
plt.title("Histograma del Área Total Ocupada", fontsize=16, fontname="Bradley Hand ITC")
plt.xlabel("Superficie (km²)", fontsize=12)
plt.ylabel("Número de Ciudades", fontsize=12)
plt.legend()

# --- 3. Gráfico de dispersión (Área de agua vs Población)
plt.subplot(2, 2, 3)
plt.scatter(df_cities["water_km2"], df_cities["population"], color="green", alpha=0.7)
plt.title("Población por kilómetro cuadrado de agua", fontsize=16)
plt.xlabel("Área de agua en la ciudad (km²)", fontsize=12)
plt.ylabel("Población (miles)", fontsize=12)
plt.annotate(
    "Outliers",
    xy=(120, 3884307),
    xytext=(60, 2000000),
    arrowprops=dict(facecolor="black", arrowstyle="->"),
    fontsize=10,
)

# --- 4. Boxplot (Altitud de las ciudades)
plt.subplot(2, 2, 4)
plt.boxplot(altitude_m, patch_artist=True, boxprops=dict(facecolor="red", color="black"))
plt.title("Diagrama de caja de la Altitud de las ciudades de California", fontsize=16)
plt.xlabel("Altitud (m)", fontsize=12)

# Ajustar el diseño de la figura
plt.tight_layout()
plt.show()
# Out:
# findfont: Font family 'Bradley Hand ITC' not found.
# findfont: Font family 'Bradley Hand ITC' not found.
# findfont: Font family 'Bradley Hand ITC' not found.
# findfont: Font family 'Bradley Hand ITC' not found.
# findfont: Font family 'Bradley Hand ITC' not found.
